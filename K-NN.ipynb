# %% [markdown]
# # KNN
# ## Model

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold,train_test_split,StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.utils import class_weight
from imblearn.over_sampling import RandomOverSampler
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score

# %%
# Read CSV file

data=pd.read_csv('preprocessed_UK_Accidents_2009_updated.csv',index_col='accident_index')
data=data.drop('seasons_ranges',axis=1)
x = data.drop('accident_severity', axis=1) 
y = data['accident_severity']

# %%
# Scalling data
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
# Applying PCA

#KNN is a distance-based algorithm that relies on the similarity between data points. 
#As the number of dimensions in the data increases, the distance between points becomes less informative and can lead to 
#the "curse of dimensionality". PCA can reduce the dimensionality of the data while retaining most of the information, 
#making the KNN model more efficient and accurate.

## choosing n_components using elbow method and explained_variance_ratio_

priciple_component_analayzer = PCA(n_components=15) # based on domain knowledge from feature extraction notebook
x_pca = priciple_component_analayzer.fit_transform(x_scaled)

# %%
## Data Imbalance
class_counts = y.value_counts()
class_counts
# Out:
# 1    134714
# 2     21475
# 3      2003
# Name: accident_severity, dtype: int64

# %%
## As shown above the data suffer from sever data imbalance
## Solutions:
## 1-class weights (not available in KNN)
## 2- Resampling (random resampling will be used in our case )

# %%
## Over sampling due to data imbalance 
oversampler = RandomOverSampler(random_state=10)
x_resampled, y_resampled = oversampler.fit_resample(x_pca, y)
x=pd.DataFrame(x_resampled)
y=y_resampled

# %%
## Train/Test split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=10,stratify=y)## stratify=y used to have the same ration of classes in each split

# %%
## Evaluation Metrics used: 1-accuracy 2-precision 3-recall 4-f1
## But we will be mailnly focusing on recall and f1 as they are more representative to our application, 
## where true positives and false negatives are important

# %%
# Search grid for hyperparamter tuning
x = X_train
y = y_train

# create a KNN model
knn = KNeighborsClassifier()

# define the hyperparameters to search over
param_grid = {'n_neighbors': range(3, 100, 10), 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']}

# create custom scoring functions to calculate accuracy, precision, recall, and F1 score with average='macro'
accuracy_scorer = make_scorer(accuracy_score)
precision_scorer = make_scorer(precision_score, average='micro', zero_division=0)
recall_scorer = make_scorer(recall_score, average='micro')
f1_scorer = make_scorer(f1_score, average='micro')

# perform grid search and obtain performance metrics for each combination of hyperparameters
grid_search = GridSearchCV(knn, param_grid=param_grid, cv=StratifiedKFold(n_splits=5, random_state=10, shuffle=True), scoring={'accuracy': accuracy_scorer, 'precision': precision_scorer, 'recall': recall_scorer, 'f1': f1_scorer}, refit='precision',verbose=3)

# fit the grid search to the data
grid_search.fit(x, y)

# print the best hyperparameters and corresponding performance metrics
print("Best hyperparameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
print("Best precision:", grid_search.cv_results_['mean_test_precision'][grid_search.best_index_])
print("Best recall:", grid_search.cv_results_['mean_test_recall'][grid_search.best_index_])
print("Best F1 score:", grid_search.cv_results_['mean_test_f1'][grid_search.best_index_])
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform; accuracy: (test=0.879) f1: (test=0.879) precision: (test=0.879) recall: (test=0.879) total time= 1.1min
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform; accuracy: (test=0.878) f1: (test=0.878) precision: (test=0.878) recall: (test=0.878) total time= 1.1min
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform; accuracy: (test=0.878) f1: (test=0.878) precision: (test=0.878) recall: (test=0.878) total time= 1.1min
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform; accuracy: (test=0.877) f1: (test=0.877) precision: (test=0.877) recall: (test=0.877) total time= 1.1min
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform; accuracy: (test=0.876) f1: (test=0.876) precision: (test=0.876) recall: (test=0.876) total time= 1.1min
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance; accuracy: (test=0.892) f1: (test=0.892) precision: (test=0.892) recall: (test=0.892) total time= 1.1min
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance; accuracy: (test=0.892) f1: (test=0.892) precision: (test=0.892) recall: (test=0.892) total time= 1.1min
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance; accuracy: (test=0.892) f1: (test=0.892) precision: (test=0.892) recall: (test=0.892) total time= 1.1min
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance; accuracy: (test=0.890) f1: (test=0.890) precision: (test=0.890) recall: (test=0.890) total time= 1.1min
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance; accuracy: (test=0.889) f1: (test=0.889) precision: (test=0.889) recall: (test=0.889) total time= 1.1min
# [CV 1/5] END metric=euclidean, n_neighbors=13, weights=uniform; accuracy: (test=0.757) f1: (test=0.757) precision: (test=0.757) recall: (test=0.757) total time= 2.7min
# [CV 2/5] END metric=euclidean, n_neighbors=13, weights=uniform; accuracy: (test=0.754) f1: (test=0.754) precision: (test=0.754) recall: (test=0.754) total time= 2.7min
# [CV 3/5] END metric=euclidean, n_neighbors=13, weights=uniform; accuracy: (test=0.758) f1: (test=0.758) precision: (test=0.758) recall: (test=0.758) total time= 2.6min
# [CV 4/5] END metric=euclidean, n_neighbors=13, weights=uniform; accuracy: (test=0.756) f1: (test=0.756) precision: (test=0.756) recall: (test=0.756) total time= 2.6min
# [CV 5/5] END metric=euclidean, n_neighbors=13, weights=uniform; accuracy: (test=0.758) f1: (test=0.758) precision: (test=0.758) recall: (test=0.758) total time= 2.6min
# [CV 1/5] END metric=euclidean, n_neighbors=13, weights=distance; accuracy: (test=0.852) f1: (test=0.852) precision: (test=0.852) recall: (test=0.852) total time= 2.6min
# [CV 2/5] END metric=euclidean, n_neighbors=13, weights=distance; accuracy: (test=0.851) f1: (test=0.851) precision: (test=0.851) recall: (test=0.851) total time= 2.6min
# [CV 3/5] END metric=euclidean, n_neighbors=13, weights=distance; accuracy: (test=0.852) f1: (test=0.852) precision: (test=0.852) recall: (test=0.852) total time= 2.6min
# [CV 4/5] END metric=euclidean, n_neighbors=13, weights=distance; accuracy: (test=0.851) f1: (test=0.851) precision: (test=0.851) recall: (test=0.851) total time= 2.6min
# [CV 5/5] END metric=euclidean, n_neighbors=13, weights=distance; accuracy: (test=0.851) f1: (test=0.851) precision: (test=0.851) recall: (test=0.851) total time= 2.6min
# [CV 1/5] END metric=euclidean, n_neighbors=23, weights=uniform; accuracy: (test=0.720) f1: (test=0.720) precision: (test=0.720) recall: (test=0.720) total time= 3.2min
# [CV 2/5] END metric=euclidean, n_neighbors=23, weights=uniform; accuracy: (test=0.714) f1: (test=0.714) precision: (test=0.714) recall: (test=0.714) total time= 3.2min
# [CV 3/5] END metric=euclidean, n_neighbors=23, weights=uniform; accuracy: (test=0.718) f1: (test=0.718) precision: (test=0.718) recall: (test=0.718) total time= 3.2min
# [CV 4/5] END metric=euclidean, n_neighbors=23, weights=uniform; accuracy: (test=0.719) f1: (test=0.719) precision: (test=0.719) recall: (test=0.719) total time= 3.2min
# [CV 5/5] END metric=euclidean, n_neighbors=23, weights=uniform; accuracy: (test=0.717) f1: (test=0.717) precision: (test=0.717) recall: (test=0.717) total time= 3.2min
# [CV 1/5] END metric=euclidean, n_neighbors=23, weights=distance; accuracy: (test=0.844) f1: (test=0.844) precision: (test=0.844) recall: (test=0.844) total time= 3.2min
# [CV 2/5] END metric=euclidean, n_neighbors=23, weights=distance; accuracy: (test=0.844) f1: (test=0.844) precision: (test=0.844) recall: (test=0.844) total time= 3.3min
# [CV 3/5] END metric=euclidean, n_neighbors=23, weights=distance; accuracy: (test=0.844) f1: (test=0.844) precision: (test=0.844) recall: (test=0.844) total time= 3.2min
# [CV 4/5] END metric=euclidean, n_neighbors=23, weights=distance; accuracy: (test=0.844) f1: (test=0.844) precision: (test=0.844) recall: (test=0.844) total time= 3.2min
# [CV 5/5] END metric=euclidean, n_neighbors=23, weights=distance; accuracy: (test=0.843) f1: (test=0.843) precision: (test=0.843) recall: (test=0.843) total time= 3.2min
# [CV 1/5] END metric=euclidean, n_neighbors=33, weights=uniform; accuracy: (test=0.691) f1: (test=0.691) precision: (test=0.691) recall: (test=0.691) total time= 3.6min
# [CV 2/5] END metric=euclidean, n_neighbors=33, weights=uniform; accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.688) recall: (test=0.688) total time= 3.6min
# [CV 3/5] END metric=euclidean, n_neighbors=33, weights=uniform; accuracy: (test=0.691) f1: (test=0.691) precision: (test=0.691) recall: (test=0.691) total time= 3.7min
# [CV 4/5] END metric=euclidean, n_neighbors=33, weights=uniform; accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.688) recall: (test=0.688) total time= 5.6min
# [CV 5/5] END metric=euclidean, n_neighbors=33, weights=uniform; accuracy: (test=0.689) f1: (test=0.689) precision: (test=0.689) recall: (test=0.689) total time= 3.9min
# [CV 1/5] END metric=euclidean, n_neighbors=33, weights=distance; accuracy: (test=0.838) f1: (test=0.838) precision: (test=0.838) recall: (test=0.838) total time= 3.7min
# [CV 2/5] END metric=euclidean, n_neighbors=33, weights=distance; accuracy: (test=0.836) f1: (test=0.836) precision: (test=0.836) recall: (test=0.836) total time= 3.7min
# [CV 3/5] END metric=euclidean, n_neighbors=33, weights=distance; accuracy: (test=0.836) f1: (test=0.836) precision: (test=0.836) recall: (test=0.836) total time= 3.6min
# [CV 4/5] END metric=euclidean, n_neighbors=33, weights=distance; accuracy: (test=0.837) f1: (test=0.837) precision: (test=0.837) recall: (test=0.837) total time= 3.6min
# [CV 5/5] END metric=euclidean, n_neighbors=33, weights=distance; accuracy: (test=0.835) f1: (test=0.835) precision: (test=0.835) recall: (test=0.835) total time= 3.5min
# [CV 1/5] END metric=euclidean, n_neighbors=43, weights=uniform; accuracy: (test=0.668) f1: (test=0.668) precision: (test=0.668) recall: (test=0.668) total time= 4.2min
# [CV 2/5] END metric=euclidean, n_neighbors=43, weights=uniform; accuracy: (test=0.665) f1: (test=0.665) precision: (test=0.665) recall: (test=0.665) total time= 4.3min
# [CV 3/5] END metric=euclidean, n_neighbors=43, weights=uniform; accuracy: (test=0.671) f1: (test=0.671) precision: (test=0.671) recall: (test=0.671) total time= 4.3min
# [CV 4/5] END metric=euclidean, n_neighbors=43, weights=uniform; accuracy: (test=0.667) f1: (test=0.667) precision: (test=0.667) recall: (test=0.667) total time= 4.3min
# [CV 5/5] END metric=euclidean, n_neighbors=43, weights=uniform; accuracy: (test=0.665) f1: (test=0.665) precision: (test=0.665) recall: (test=0.665) total time= 4.3min
# [CV 1/5] END metric=euclidean, n_neighbors=43, weights=distance; accuracy: (test=0.832) f1: (test=0.832) precision: (test=0.832) recall: (test=0.832) total time= 4.3min
# [CV 2/5] END metric=euclidean, n_neighbors=43, weights=distance; accuracy: (test=0.830) f1: (test=0.830) precision: (test=0.830) recall: (test=0.830) total time= 4.3min
# [CV 3/5] END metric=euclidean, n_neighbors=43, weights=distance; accuracy: (test=0.831) f1: (test=0.831) precision: (test=0.831) recall: (test=0.831) total time= 4.2min
# [CV 4/5] END metric=euclidean, n_neighbors=43, weights=distance; accuracy: (test=0.830) f1: (test=0.830) precision: (test=0.830) recall: (test=0.830) total time= 4.2min
# [CV 5/5] END metric=euclidean, n_neighbors=43, weights=distance; accuracy: (test=0.830) f1: (test=0.830) precision: (test=0.830) recall: (test=0.830) total time= 4.3min
# [CV 1/5] END metric=euclidean, n_neighbors=53, weights=uniform; accuracy: (test=0.649) f1: (test=0.649) precision: (test=0.649) recall: (test=0.649) total time= 5.2min
# [CV 2/5] END metric=euclidean, n_neighbors=53, weights=uniform; accuracy: (test=0.646) f1: (test=0.646) precision: (test=0.646) recall: (test=0.646) total time= 5.2min
# [CV 3/5] END metric=euclidean, n_neighbors=53, weights=uniform; accuracy: (test=0.650) f1: (test=0.650) precision: (test=0.650) recall: (test=0.650) total time= 5.2min
# [CV 4/5] END metric=euclidean, n_neighbors=53, weights=uniform; accuracy: (test=0.647) f1: (test=0.647) precision: (test=0.647) recall: (test=0.647) total time= 5.1min
# [CV 5/5] END metric=euclidean, n_neighbors=53, weights=uniform; accuracy: (test=0.647) f1: (test=0.647) precision: (test=0.647) recall: (test=0.647) total time= 5.1min
# [CV 1/5] END metric=euclidean, n_neighbors=53, weights=distance; accuracy: (test=0.826) f1: (test=0.826) precision: (test=0.826) recall: (test=0.826) total time= 5.1min
# [CV 2/5] END metric=euclidean, n_neighbors=53, weights=distance; accuracy: (test=0.825) f1: (test=0.825) precision: (test=0.825) recall: (test=0.825) total time= 5.1min
# [CV 3/5] END metric=euclidean, n_neighbors=53, weights=distance; accuracy: (test=0.826) f1: (test=0.826) precision: (test=0.826) recall: (test=0.826) total time= 5.1min
# [CV 4/5] END metric=euclidean, n_neighbors=53, weights=distance; accuracy: (test=0.825) f1: (test=0.825) precision: (test=0.825) recall: (test=0.825) total time= 5.0min
# [CV 5/5] END metric=euclidean, n_neighbors=53, weights=distance; accuracy: (test=0.824) f1: (test=0.824) precision: (test=0.824) recall: (test=0.824) total time= 5.0min
# [CV 1/5] END metric=euclidean, n_neighbors=63, weights=uniform; accuracy: (test=0.632) f1: (test=0.632) precision: (test=0.632) recall: (test=0.632) total time= 5.8min
# [CV 2/5] END metric=euclidean, n_neighbors=63, weights=uniform; accuracy: (test=0.630) f1: (test=0.630) precision: (test=0.630) recall: (test=0.630) total time= 5.7min
# [CV 3/5] END metric=euclidean, n_neighbors=63, weights=uniform; accuracy: (test=0.634) f1: (test=0.634) precision: (test=0.634) recall: (test=0.634) total time= 5.7min
# [CV 4/5] END metric=euclidean, n_neighbors=63, weights=uniform; accuracy: (test=0.632) f1: (test=0.632) precision: (test=0.632) recall: (test=0.632) total time= 5.7min
# [CV 5/5] END metric=euclidean, n_neighbors=63, weights=uniform; accuracy: (test=0.631) f1: (test=0.631) precision: (test=0.631) recall: (test=0.631) total time= 5.7min
# [CV 1/5] END metric=euclidean, n_neighbors=63, weights=distance; accuracy: (test=0.823) f1: (test=0.823) precision: (test=0.823) recall: (test=0.823) total time= 5.7min
# [CV 2/5] END metric=euclidean, n_neighbors=63, weights=distance; accuracy: (test=0.821) f1: (test=0.821) precision: (test=0.821) recall: (test=0.821) total time= 5.7min
# [CV 3/5] END metric=euclidean, n_neighbors=63, weights=distance; accuracy: (test=0.822) f1: (test=0.822) precision: (test=0.822) recall: (test=0.822) total time= 5.7min
# [CV 4/5] END metric=euclidean, n_neighbors=63, weights=distance; accuracy: (test=0.822) f1: (test=0.822) precision: (test=0.822) recall: (test=0.822) total time= 5.7min
# [CV 5/5] END metric=euclidean, n_neighbors=63, weights=distance; accuracy: (test=0.820) f1: (test=0.820) precision: (test=0.820) recall: (test=0.820) total time= 5.7min
# [CV 1/5] END metric=euclidean, n_neighbors=73, weights=uniform; accuracy: (test=0.614) f1: (test=0.614) precision: (test=0.614) recall: (test=0.614) total time= 6.2min
# [CV 2/5] END metric=euclidean, n_neighbors=73, weights=uniform; accuracy: (test=0.613) f1: (test=0.613) precision: (test=0.613) recall: (test=0.613) total time= 6.2min
# [CV 3/5] END metric=euclidean, n_neighbors=73, weights=uniform; accuracy: (test=0.619) f1: (test=0.619) precision: (test=0.619) recall: (test=0.619) total time= 6.2min
# [CV 4/5] END metric=euclidean, n_neighbors=73, weights=uniform; accuracy: (test=0.617) f1: (test=0.617) precision: (test=0.617) recall: (test=0.617) total time= 6.1min
# [CV 5/5] END metric=euclidean, n_neighbors=73, weights=uniform; accuracy: (test=0.615) f1: (test=0.615) precision: (test=0.615) recall: (test=0.615) total time= 6.3min
# [CV 1/5] END metric=euclidean, n_neighbors=73, weights=distance; accuracy: (test=0.818) f1: (test=0.818) precision: (test=0.818) recall: (test=0.818) total time= 6.2min
# [CV 2/5] END metric=euclidean, n_neighbors=73, weights=distance; accuracy: (test=0.818) f1: (test=0.818) precision: (test=0.818) recall: (test=0.818) total time= 6.1min
# [CV 3/5] END metric=euclidean, n_neighbors=73, weights=distance; accuracy: (test=0.818) f1: (test=0.818) precision: (test=0.818) recall: (test=0.818) total time= 6.2min
# [CV 4/5] END metric=euclidean, n_neighbors=73, weights=distance; accuracy: (test=0.819) f1: (test=0.819) precision: (test=0.819) recall: (test=0.819) total time= 6.1min
# [CV 5/5] END metric=euclidean, n_neighbors=73, weights=distance; accuracy: (test=0.816) f1: (test=0.816) precision: (test=0.816) recall: (test=0.816) total time= 6.1min
# [CV 1/5] END metric=euclidean, n_neighbors=83, weights=uniform; accuracy: (test=0.601) f1: (test=0.601) precision: (test=0.601) recall: (test=0.601) total time= 6.6min
# [CV 2/5] END metric=euclidean, n_neighbors=83, weights=uniform; accuracy: (test=0.600) f1: (test=0.600) precision: (test=0.600) recall: (test=0.600) total time= 6.5min
# [CV 3/5] END metric=euclidean, n_neighbors=83, weights=uniform; accuracy: (test=0.603) f1: (test=0.603) precision: (test=0.603) recall: (test=0.603) total time= 6.6min
# [CV 4/5] END metric=euclidean, n_neighbors=83, weights=uniform; accuracy: (test=0.602) f1: (test=0.602) precision: (test=0.602) recall: (test=0.602) total time= 6.5min
# [CV 5/5] END metric=euclidean, n_neighbors=83, weights=uniform; accuracy: (test=0.600) f1: (test=0.600) precision: (test=0.600) recall: (test=0.600) total time= 6.5min
# [CV 1/5] END metric=euclidean, n_neighbors=83, weights=distance; accuracy: (test=0.815) f1: (test=0.815) precision: (test=0.815) recall: (test=0.815) total time= 6.5min
# [CV 2/5] END metric=euclidean, n_neighbors=83, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time= 6.5min
# [CV 3/5] END metric=euclidean, n_neighbors=83, weights=distance; accuracy: (test=0.815) f1: (test=0.815) precision: (test=0.815) recall: (test=0.815) total time= 6.6min
# [CV 4/5] END metric=euclidean, n_neighbors=83, weights=distance; accuracy: (test=0.816) f1: (test=0.816) precision: (test=0.816) recall: (test=0.816) total time= 6.5min
# [CV 5/5] END metric=euclidean, n_neighbors=83, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time= 6.5min
# [CV 1/5] END metric=euclidean, n_neighbors=93, weights=uniform; accuracy: (test=0.585) f1: (test=0.585) precision: (test=0.585) recall: (test=0.585) total time= 6.9min
# [CV 2/5] END metric=euclidean, n_neighbors=93, weights=uniform; accuracy: (test=0.584) f1: (test=0.584) precision: (test=0.584) recall: (test=0.584) total time= 6.8min
# [CV 3/5] END metric=euclidean, n_neighbors=93, weights=uniform; accuracy: (test=0.588) f1: (test=0.588) precision: (test=0.588) recall: (test=0.588) total time= 6.8min
# [CV 4/5] END metric=euclidean, n_neighbors=93, weights=uniform; accuracy: (test=0.587) f1: (test=0.587) precision: (test=0.587) recall: (test=0.587) total time= 6.8min
# [CV 5/5] END metric=euclidean, n_neighbors=93, weights=uniform; accuracy: (test=0.585) f1: (test=0.585) precision: (test=0.585) recall: (test=0.585) total time= 6.8min
# [CV 1/5] END metric=euclidean, n_neighbors=93, weights=distance; accuracy: (test=0.813) f1: (test=0.813) precision: (test=0.813) recall: (test=0.813) total time= 7.2min
# [CV 2/5] END metric=euclidean, n_neighbors=93, weights=distance; accuracy: (test=0.813) f1: (test=0.813) precision: (test=0.813) recall: (test=0.813) total time= 7.4min
# [CV 3/5] END metric=euclidean, n_neighbors=93, weights=distance; accuracy: (test=0.813) f1: (test=0.813) precision: (test=0.813) recall: (test=0.813) total time= 7.7min
# [CV 4/5] END metric=euclidean, n_neighbors=93, weights=distance; accuracy: (test=0.815) f1: (test=0.815) precision: (test=0.815) recall: (test=0.815) total time= 7.6min
# [CV 5/5] END metric=euclidean, n_neighbors=93, weights=distance; accuracy: (test=0.813) f1: (test=0.813) precision: (test=0.813) recall: (test=0.813) total time= 7.6min
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform; accuracy: (test=0.879) f1: (test=0.879) precision: (test=0.879) recall: (test=0.879) total time= 1.9min
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform; accuracy: (test=0.878) f1: (test=0.878) precision: (test=0.878) recall: (test=0.878) total time= 1.9min
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform; accuracy: (test=0.880) f1: (test=0.880) precision: (test=0.880) recall: (test=0.880) total time= 1.9min
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform; accuracy: (test=0.878) f1: (test=0.878) precision: (test=0.878) recall: (test=0.878) total time= 1.9min
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform; accuracy: (test=0.879) f1: (test=0.879) precision: (test=0.879) recall: (test=0.879) total time= 1.9min
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance; accuracy: (test=0.893) f1: (test=0.893) precision: (test=0.893) recall: (test=0.893) total time= 1.9min
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance; accuracy: (test=0.892) f1: (test=0.892) precision: (test=0.892) recall: (test=0.892) total time= 1.9min
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance; accuracy: (test=0.894) f1: (test=0.894) precision: (test=0.894) recall: (test=0.894) total time= 1.9min
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance; accuracy: (test=0.892) f1: (test=0.892) precision: (test=0.892) recall: (test=0.892) total time= 1.9min
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance; accuracy: (test=0.892) f1: (test=0.892) precision: (test=0.892) recall: (test=0.892) total time= 1.8min
# [CV 1/5] END metric=manhattan, n_neighbors=13, weights=uniform; accuracy: (test=0.757) f1: (test=0.757) precision: (test=0.757) recall: (test=0.757) total time= 4.7min
# [CV 2/5] END metric=manhattan, n_neighbors=13, weights=uniform; accuracy: (test=0.755) f1: (test=0.755) precision: (test=0.755) recall: (test=0.755) total time= 4.7min
# [CV 3/5] END metric=manhattan, n_neighbors=13, weights=uniform; accuracy: (test=0.757) f1: (test=0.757) precision: (test=0.757) recall: (test=0.757) total time= 4.7min
# [CV 4/5] END metric=manhattan, n_neighbors=13, weights=uniform; accuracy: (test=0.757) f1: (test=0.757) precision: (test=0.757) recall: (test=0.757) total time= 4.6min
# [CV 5/5] END metric=manhattan, n_neighbors=13, weights=uniform; accuracy: (test=0.758) f1: (test=0.758) precision: (test=0.758) recall: (test=0.758) total time= 4.6min
# [CV 1/5] END metric=manhattan, n_neighbors=13, weights=distance; accuracy: (test=0.853) f1: (test=0.853) precision: (test=0.853) recall: (test=0.853) total time= 4.6min
# [CV 2/5] END metric=manhattan, n_neighbors=13, weights=distance; accuracy: (test=0.853) f1: (test=0.853) precision: (test=0.853) recall: (test=0.853) total time= 4.6min
# [CV 3/5] END metric=manhattan, n_neighbors=13, weights=distance; accuracy: (test=0.853) f1: (test=0.853) precision: (test=0.853) recall: (test=0.853) total time= 4.6min
# [CV 4/5] END metric=manhattan, n_neighbors=13, weights=distance; accuracy: (test=0.853) f1: (test=0.853) precision: (test=0.853) recall: (test=0.853) total time= 4.6min
# [CV 5/5] END metric=manhattan, n_neighbors=13, weights=distance; accuracy: (test=0.852) f1: (test=0.852) precision: (test=0.852) recall: (test=0.852) total time= 4.7min
# [CV 1/5] END metric=manhattan, n_neighbors=23, weights=uniform; accuracy: (test=0.721) f1: (test=0.721) precision: (test=0.721) recall: (test=0.721) total time= 5.7min
# [CV 2/5] END metric=manhattan, n_neighbors=23, weights=uniform; accuracy: (test=0.716) f1: (test=0.716) precision: (test=0.716) recall: (test=0.716) total time= 5.6min
# [CV 3/5] END metric=manhattan, n_neighbors=23, weights=uniform; accuracy: (test=0.720) f1: (test=0.720) precision: (test=0.720) recall: (test=0.720) total time= 5.5min
# [CV 4/5] END metric=manhattan, n_neighbors=23, weights=uniform; accuracy: (test=0.720) f1: (test=0.720) precision: (test=0.720) recall: (test=0.720) total time= 5.6min
# [CV 5/5] END metric=manhattan, n_neighbors=23, weights=uniform; accuracy: (test=0.717) f1: (test=0.717) precision: (test=0.717) recall: (test=0.717) total time= 5.5min
# [CV 1/5] END metric=manhattan, n_neighbors=23, weights=distance; accuracy: (test=0.846) f1: (test=0.846) precision: (test=0.846) recall: (test=0.846) total time= 5.4min
# [CV 2/5] END metric=manhattan, n_neighbors=23, weights=distance; accuracy: (test=0.844) f1: (test=0.844) precision: (test=0.844) recall: (test=0.844) total time= 5.4min
# [CV 3/5] END metric=manhattan, n_neighbors=23, weights=distance; accuracy: (test=0.845) f1: (test=0.845) precision: (test=0.845) recall: (test=0.845) total time= 5.6min
# [CV 4/5] END metric=manhattan, n_neighbors=23, weights=distance; accuracy: (test=0.845) f1: (test=0.845) precision: (test=0.845) recall: (test=0.845) total time= 5.5min
# [CV 5/5] END metric=manhattan, n_neighbors=23, weights=distance; accuracy: (test=0.843) f1: (test=0.843) precision: (test=0.843) recall: (test=0.843) total time= 5.6min
# [CV 1/5] END metric=manhattan, n_neighbors=33, weights=uniform; accuracy: (test=0.691) f1: (test=0.691) precision: (test=0.691) recall: (test=0.691) total time= 6.2min
# [CV 2/5] END metric=manhattan, n_neighbors=33, weights=uniform; accuracy: (test=0.690) f1: (test=0.690) precision: (test=0.690) recall: (test=0.690) total time= 6.2min
# [CV 3/5] END metric=manhattan, n_neighbors=33, weights=uniform; accuracy: (test=0.692) f1: (test=0.692) precision: (test=0.692) recall: (test=0.692) total time= 6.2min
# [CV 4/5] END metric=manhattan, n_neighbors=33, weights=uniform; accuracy: (test=0.691) f1: (test=0.691) precision: (test=0.691) recall: (test=0.691) total time= 6.0min
# [CV 5/5] END metric=manhattan, n_neighbors=33, weights=uniform; accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.688) recall: (test=0.688) total time= 6.1min
# [CV 1/5] END metric=manhattan, n_neighbors=33, weights=distance; accuracy: (test=0.839) f1: (test=0.839) precision: (test=0.839) recall: (test=0.839) total time= 6.3min
# [CV 2/5] END metric=manhattan, n_neighbors=33, weights=distance; accuracy: (test=0.837) f1: (test=0.837) precision: (test=0.837) recall: (test=0.837) total time= 6.2min
# [CV 3/5] END metric=manhattan, n_neighbors=33, weights=distance; accuracy: (test=0.838) f1: (test=0.838) precision: (test=0.838) recall: (test=0.838) total time= 6.2min
# [CV 4/5] END metric=manhattan, n_neighbors=33, weights=distance; accuracy: (test=0.839) f1: (test=0.839) precision: (test=0.839) recall: (test=0.839) total time= 6.0min
# [CV 5/5] END metric=manhattan, n_neighbors=33, weights=distance; accuracy: (test=0.836) f1: (test=0.836) precision: (test=0.836) recall: (test=0.836) total time= 6.0min
# [CV 1/5] END metric=manhattan, n_neighbors=43, weights=uniform; accuracy: (test=0.670) f1: (test=0.670) precision: (test=0.670) recall: (test=0.670) total time= 7.0min
# [CV 2/5] END metric=manhattan, n_neighbors=43, weights=uniform; accuracy: (test=0.668) f1: (test=0.668) precision: (test=0.668) recall: (test=0.668) total time= 6.9min
# [CV 3/5] END metric=manhattan, n_neighbors=43, weights=uniform; accuracy: (test=0.671) f1: (test=0.671) precision: (test=0.671) recall: (test=0.671) total time= 6.9min
# [CV 4/5] END metric=manhattan, n_neighbors=43, weights=uniform; accuracy: (test=0.670) f1: (test=0.670) precision: (test=0.670) recall: (test=0.670) total time= 6.9min
# [CV 5/5] END metric=manhattan, n_neighbors=43, weights=uniform; accuracy: (test=0.667) f1: (test=0.667) precision: (test=0.667) recall: (test=0.667) total time= 6.9min
# [CV 1/5] END metric=manhattan, n_neighbors=43, weights=distance; accuracy: (test=0.833) f1: (test=0.833) precision: (test=0.833) recall: (test=0.833) total time= 6.9min
# [CV 2/5] END metric=manhattan, n_neighbors=43, weights=distance; accuracy: (test=0.832) f1: (test=0.832) precision: (test=0.832) recall: (test=0.832) total time= 6.9min
# [CV 3/5] END metric=manhattan, n_neighbors=43, weights=distance; accuracy: (test=0.832) f1: (test=0.832) precision: (test=0.832) recall: (test=0.832) total time= 6.9min
# [CV 4/5] END metric=manhattan, n_neighbors=43, weights=distance; accuracy: (test=0.832) f1: (test=0.832) precision: (test=0.832) recall: (test=0.832) total time= 6.9min
# [CV 5/5] END metric=manhattan, n_neighbors=43, weights=distance; accuracy: (test=0.831) f1: (test=0.831) precision: (test=0.831) recall: (test=0.831) total time= 6.9min
# [CV 1/5] END metric=manhattan, n_neighbors=53, weights=uniform; accuracy: (test=0.653) f1: (test=0.653) precision: (test=0.653) recall: (test=0.653) total time= 8.4min
# [CV 2/5] END metric=manhattan, n_neighbors=53, weights=uniform; accuracy: (test=0.649) f1: (test=0.649) precision: (test=0.649) recall: (test=0.649) total time= 8.4min
# [CV 3/5] END metric=manhattan, n_neighbors=53, weights=uniform; accuracy: (test=0.652) f1: (test=0.652) precision: (test=0.652) recall: (test=0.652) total time= 8.4min
# [CV 4/5] END metric=manhattan, n_neighbors=53, weights=uniform; accuracy: (test=0.649) f1: (test=0.649) precision: (test=0.649) recall: (test=0.649) total time= 8.6min
# [CV 5/5] END metric=manhattan, n_neighbors=53, weights=uniform; accuracy: (test=0.649) f1: (test=0.649) precision: (test=0.649) recall: (test=0.649) total time= 8.5min
# [CV 1/5] END metric=manhattan, n_neighbors=53, weights=distance; accuracy: (test=0.829) f1: (test=0.829) precision: (test=0.829) recall: (test=0.829) total time= 8.6min
# [CV 2/5] END metric=manhattan, n_neighbors=53, weights=distance; accuracy: (test=0.826) f1: (test=0.826) precision: (test=0.826) recall: (test=0.826) total time= 8.8min
# [CV 3/5] END metric=manhattan, n_neighbors=53, weights=distance; accuracy: (test=0.827) f1: (test=0.827) precision: (test=0.827) recall: (test=0.827) total time= 8.7min
# [CV 4/5] END metric=manhattan, n_neighbors=53, weights=distance; accuracy: (test=0.827) f1: (test=0.827) precision: (test=0.827) recall: (test=0.827) total time= 8.7min
# [CV 5/5] END metric=manhattan, n_neighbors=53, weights=distance; accuracy: (test=0.826) f1: (test=0.826) precision: (test=0.826) recall: (test=0.826) total time= 8.8min
# [CV 1/5] END metric=manhattan, n_neighbors=63, weights=uniform; accuracy: (test=0.635) f1: (test=0.635) precision: (test=0.635) recall: (test=0.635) total time= 9.8min
# [CV 2/5] END metric=manhattan, n_neighbors=63, weights=uniform; accuracy: (test=0.632) f1: (test=0.632) precision: (test=0.632) recall: (test=0.632) total time= 9.6min
# [CV 3/5] END metric=manhattan, n_neighbors=63, weights=uniform; accuracy: (test=0.637) f1: (test=0.637) precision: (test=0.637) recall: (test=0.637) total time= 9.6min
# [CV 4/5] END metric=manhattan, n_neighbors=63, weights=uniform; accuracy: (test=0.633) f1: (test=0.633) precision: (test=0.633) recall: (test=0.633) total time= 9.6min
# [CV 5/5] END metric=manhattan, n_neighbors=63, weights=uniform; accuracy: (test=0.633) f1: (test=0.633) precision: (test=0.633) recall: (test=0.633) total time= 9.9min
# [CV 1/5] END metric=manhattan, n_neighbors=63, weights=distance; accuracy: (test=0.823) f1: (test=0.823) precision: (test=0.823) recall: (test=0.823) total time= 9.9min
# [CV 2/5] END metric=manhattan, n_neighbors=63, weights=distance; accuracy: (test=0.822) f1: (test=0.822) precision: (test=0.822) recall: (test=0.822) total time= 9.7min
# [CV 3/5] END metric=manhattan, n_neighbors=63, weights=distance; accuracy: (test=0.822) f1: (test=0.822) precision: (test=0.822) recall: (test=0.822) total time= 9.7min
# [CV 4/5] END metric=manhattan, n_neighbors=63, weights=distance; accuracy: (test=0.823) f1: (test=0.823) precision: (test=0.823) recall: (test=0.823) total time= 9.6min
# [CV 5/5] END metric=manhattan, n_neighbors=63, weights=distance; accuracy: (test=0.822) f1: (test=0.822) precision: (test=0.822) recall: (test=0.822) total time= 9.8min
# [CV 1/5] END metric=manhattan, n_neighbors=73, weights=uniform; accuracy: (test=0.618) f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) total time=10.6min
# [CV 2/5] END metric=manhattan, n_neighbors=73, weights=uniform; accuracy: (test=0.617) f1: (test=0.617) precision: (test=0.617) recall: (test=0.617) total time=10.5min
# [CV 3/5] END metric=manhattan, n_neighbors=73, weights=uniform; accuracy: (test=0.621) f1: (test=0.621) precision: (test=0.621) recall: (test=0.621) total time=10.6min
# [CV 4/5] END metric=manhattan, n_neighbors=73, weights=uniform; accuracy: (test=0.616) f1: (test=0.616) precision: (test=0.616) recall: (test=0.616) total time=10.5min
# [CV 5/5] END metric=manhattan, n_neighbors=73, weights=uniform; accuracy: (test=0.618) f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) total time=10.5min
# [CV 1/5] END metric=manhattan, n_neighbors=73, weights=distance; accuracy: (test=0.819) f1: (test=0.819) precision: (test=0.819) recall: (test=0.819) total time=10.3min
# [CV 2/5] END metric=manhattan, n_neighbors=73, weights=distance; accuracy: (test=0.818) f1: (test=0.818) precision: (test=0.818) recall: (test=0.818) total time=10.5min
# [CV 3/5] END metric=manhattan, n_neighbors=73, weights=distance; accuracy: (test=0.819) f1: (test=0.819) precision: (test=0.819) recall: (test=0.819) total time=10.5min
# [CV 4/5] END metric=manhattan, n_neighbors=73, weights=distance; accuracy: (test=0.819) f1: (test=0.819) precision: (test=0.819) recall: (test=0.819) total time=10.4min
# [CV 5/5] END metric=manhattan, n_neighbors=73, weights=distance; accuracy: (test=0.817) f1: (test=0.817) precision: (test=0.817) recall: (test=0.817) total time=10.4min
# [CV 1/5] END metric=manhattan, n_neighbors=83, weights=uniform; accuracy: (test=0.606) f1: (test=0.606) precision: (test=0.606) recall: (test=0.606) total time=10.8min
# [CV 2/5] END metric=manhattan, n_neighbors=83, weights=uniform; accuracy: (test=0.602) f1: (test=0.602) precision: (test=0.602) recall: (test=0.602) total time=10.8min
# [CV 3/5] END metric=manhattan, n_neighbors=83, weights=uniform; accuracy: (test=0.604) f1: (test=0.604) precision: (test=0.604) recall: (test=0.604) total time=10.6min
# [CV 4/5] END metric=manhattan, n_neighbors=83, weights=uniform; accuracy: (test=0.600) f1: (test=0.600) precision: (test=0.600) recall: (test=0.600) total time=10.6min
# [CV 5/5] END metric=manhattan, n_neighbors=83, weights=uniform; accuracy: (test=0.601) f1: (test=0.601) precision: (test=0.601) recall: (test=0.601) total time=10.9min
# [CV 1/5] END metric=manhattan, n_neighbors=83, weights=distance; accuracy: (test=0.817) f1: (test=0.817) precision: (test=0.817) recall: (test=0.817) total time=11.1min
# [CV 2/5] END metric=manhattan, n_neighbors=83, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time=10.8min
# [CV 3/5] END metric=manhattan, n_neighbors=83, weights=distance; accuracy: (test=0.815) f1: (test=0.815) precision: (test=0.815) recall: (test=0.815) total time=10.8min
# [CV 4/5] END metric=manhattan, n_neighbors=83, weights=distance; accuracy: (test=0.815) f1: (test=0.815) precision: (test=0.815) recall: (test=0.815) total time=10.7min
# [CV 5/5] END metric=manhattan, n_neighbors=83, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time=11.0min
# [CV 1/5] END metric=manhattan, n_neighbors=93, weights=uniform; accuracy: (test=0.590) f1: (test=0.590) precision: (test=0.590) recall: (test=0.590) total time=11.5min
# [CV 2/5] END metric=manhattan, n_neighbors=93, weights=uniform; accuracy: (test=0.586) f1: (test=0.586) precision: (test=0.586) recall: (test=0.586) total time=11.5min
# [CV 3/5] END metric=manhattan, n_neighbors=93, weights=uniform; accuracy: (test=0.589) f1: (test=0.589) precision: (test=0.589) recall: (test=0.589) total time=11.2min
# [CV 4/5] END metric=manhattan, n_neighbors=93, weights=uniform; accuracy: (test=0.587) f1: (test=0.587) precision: (test=0.587) recall: (test=0.587) total time=11.4min
# [CV 5/5] END metric=manhattan, n_neighbors=93, weights=uniform; accuracy: (test=0.586) f1: (test=0.586) precision: (test=0.586) recall: (test=0.586) total time=11.2min
# [CV 1/5] END metric=manhattan, n_neighbors=93, weights=distance; accuracy: (test=0.815) f1: (test=0.815) precision: (test=0.815) recall: (test=0.815) total time=11.2min
# [CV 2/5] END metric=manhattan, n_neighbors=93, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time=11.6min
# [CV 3/5] END metric=manhattan, n_neighbors=93, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time=11.8min
# [CV 4/5] END metric=manhattan, n_neighbors=93, weights=distance; accuracy: (test=0.814) f1: (test=0.814) precision: (test=0.814) recall: (test=0.814) total time=11.2min
# [CV 5/5] END metric=manhattan, n_neighbors=93, weights=distance; accuracy: (test=0.813) f1: (test=0.813) precision: (test=0.813) recall: (test=0.813) total time=11.1min
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Best accuracy: 0.8926117838844899
# Best precision: 0.8926117838844899
# Best recall: 0.8926117838844899
# Best F1 score: 0.8926117838844899

# %%
KNN = KNeighborsClassifier(n_neighbors=3,metric='manhattan',weights='distance')
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = cross_validate(KNN, x, y, cv=skf, scoring='f1_micro')
print(sum(results) / len(results))

# %%
KNN = KNeighborsClassifier(n_neighbors=3,metric='manhattan',weights='distance')
# Train the model on the training data
KNN.fit(X_train, y_train)

# Evaluate the performance of the model on the training and testing data
y_train_pred = KNN.predict(X_train)
y_test_pred = KNN.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

train_f1 = f1_score(y_train, y_train_pred, average='micro')
test_f1 = f1_score(y_test, y_test_pred, average='micro')

train_precision = precision_score(y_train, y_train_pred, average='micro')
test_precision = precision_score(y_test, y_test_pred, average='micro')

train_recall = recall_score(y_train, y_train_pred, average='micro')
test_recall = recall_score(y_test, y_test_pred, average='micro')

# Print the evaluation metrics
print("Training accuracy:", train_accuracy)
print("Testing accuracy:", test_accuracy)

print("Training F1 score:", train_f1)
print("Testing F1 score:", test_f1)

print("Training precision:", train_precision)
print("Testing precision:", test_precision)

print("Training recall:", train_recall)
print("Testing recall:", test_recall)
# Out:
# Training accuracy: 0.9999970889613414
# Testing accuracy: 0.9083995909075913
# Training F1 score: 0.9999970889613414
# Testing F1 score: 0.9083995909075913
# Training precision: 0.9999970889613414
# Testing precision: 0.9083995909075913
# Training recall: 0.9999970889613414
# Testing recall: 0.9083995909075913

# %%
## The results show that the model is doing well and not overfitting

# %%
# KNN can be a good option for imbalanced data because it is a non-parametric algorithm that does not make any 
# assumptions, like the assumptions made in NB for example, about the underlying distribution of the data. 
# KNN simply classifies new examples based on the class labels of their nearest neighbors in the training data.

# Moreover, KNN is robust against outliers than other algorithms. 
# Outliers can have a significant impact on the decision boundary of a classifier, and can lead to poor performance 
# on the minority class. However, KNN can be less sensitive to outliers because it simply considers the k nearest neighbors, 
# rather than trying to fit a complex decision boundary.
